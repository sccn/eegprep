# %%
import sys

# %%
sys.path.insert(0, '/Users/dtyoung/Documents/EEGLAB/eegprep/src/')

# %%
import mne

filepath = '/Users/arno/Python/eeg-ssl/data_small/ds005510/sub-NDARAB348EWR/eeg/sub-NDARAB348EWR_task-RestingState_eeg.set'
filepath = '/Users/arno/matlab/eeglab_versions/eeglab2025.0.0/sample_data/eeglab_data.set'
raw = mne.io.read_raw_eeglab(filepath, preload=True)
print(raw.get_data()[-1])
print(raw.get_data()[-3])
raw.plot( show=False, scalings='auto')
# Out:
# Reading /Users/arno/matlab/eeglab_versions/eeglab2025.0.0/sample_data/eeglab_data.fdt
# Reading 0 ... 30503  =      0.000 ...   238.305 secs...
# [-9.50714016e-06  7.33757973e-06  1.53450775e-06 ...  1.77253227e-05
#   9.55638695e-06  1.28716125e-05]
# [-1.50906496e-05 -2.31424665e-06 -6.38855410e-06 ...  7.32922125e-06
#   3.90093350e-06  1.25172253e-05]
# Using matplotlib as 2D backend.
# <MNEBrowseFigure size 800x800 with 4 Axes>
# <MNEBrowseFigure size 800x800 with 4 Axes>

# %%
raw = mne.io.read_raw_eeglab(filepath, preload=False)
print(raw.get_data()[-1])
print(raw.get_data()[-3])
raw.plot( show=False, scalings='auto')
# Out:
# Reading /Users/arno/matlab/eeglab_versions/eeglab2025.0.0/sample_data/eeglab_data.fdt
# [-9.50714016e-06  7.33757973e-06  1.53450775e-06 ...  1.77253227e-05
#   9.55638695e-06  1.28716125e-05]
# [-1.50906496e-05 -2.31424665e-06 -6.38855410e-06 ...  7.32922125e-06
#   3.90093350e-06  1.25172253e-05]
# <MNEBrowseFigure size 800x800 with 4 Axes>
